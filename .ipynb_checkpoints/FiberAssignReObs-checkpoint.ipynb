# %%
import os,sys,glob,fitsio,subprocess
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import numpy as np
import healpy as hp
import astropy.io
from astropy.io import fits
from astropy.table import Table, Column
import desimodel.io
import desimodel.footprint
import matplotlib.style
import matplotlib as mpl
from desitarget import mtl
from desisim.quickcat import quickcat
from desitarget.targetmask import desi_mask, obsconditions
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # **Setting output path for this notebook**

# %%
# Change this path if you want
outdir= os.path.join(os.environ['SCRATCH'],'desi/priority_tests/')
os.makedirs(outdir, exist_ok=True)
os.chdir(outdir)
print('Working on {}'.format(outdir))
# Out:
# Working on /global/cscratch1/sd/andsouza/desi/priority_tests/

# %% [markdown]
# # **Selecting the Year 1 footprint from a surveysim**

# %% [markdown]
# First we read the exposure.fits file from surveysims path

# %%
sim_path = "/project/projectdirs/desi/datachallenge/surveysim2018/weather/035/"
exposures = Table.read(os.path.join(sim_path,'exposures.fits'), hdu=1)
exposures[:5]
# Out:
# <Table length=5>
#        MJD         EXPTIME TILEID  SNR2FRAC  ...   SEEING     TRANSP     SKY
#      float64       float32 int32   float32   ...  float32    float32   float32
# ------------------ ------- ------ ---------- ... ---------- ---------- -------
# 58819.063888888886   920.0  28576  0.5002821 ...    1.01959  0.9735375     1.0
#  58819.07523148129   660.0  28576    1.00477 ...  0.9895672  0.9818349     1.0
#  58819.08425925893  1080.0  28589 0.50211537 ...  1.1533324 0.96132696     1.0
#  58819.09745370316   650.0  28589  1.0113196 ... 0.87564546  0.9578879     1.0
#  58819.10636574006   610.0  28588  0.5042863 ... 0.77289426  0.9925911     1.0

# %% [markdown]
# Find which tiles are covered during the first year

# %%
cadence=365
w=np.where(np.int_((exposures['MJD']-exposures['MJD'].min())/cadence)==0)

# %%
year1=exposures[w]
year1[:5]
# Out:
# <Table length=5>
#        MJD         EXPTIME TILEID  SNR2FRAC  ...   SEEING     TRANSP     SKY
#      float64       float32 int32   float32   ...  float32    float32   float32
# ------------------ ------- ------ ---------- ... ---------- ---------- -------
# 58819.063888888886   920.0  28576  0.5002821 ...    1.01959  0.9735375     1.0
#  58819.07523148129   660.0  28576    1.00477 ...  0.9895672  0.9818349     1.0
#  58819.08425925893  1080.0  28589 0.50211537 ...  1.1533324 0.96132696     1.0
#  58819.09745370316   650.0  28589  1.0113196 ... 0.87564546  0.9578879     1.0
#  58819.10636574006   610.0  28588  0.5042863 ... 0.77289426  0.9925911     1.0

# %% [markdown]
# For this test we will use a small area, so first we will get those tiles in a 100 sq.deg

# %% [markdown]
# ### **Reducing by area**

# %%
alltiles = Table(desimodel.io.load_tiles())
dark = alltiles['PROGRAM'] == 'DARK' # We are only DARK targets
tiles= alltiles[dark]

# Change this line if needed, if not needed comment, next twolines
ii = (150 < tiles['RA']) & (tiles['RA']<160) & (20<tiles['DEC']) & (tiles['DEC']<30)
tiles=tiles[ii]

print('There are {} tiles in this area.'.format(len(tiles)))
# Out:
# There are 50 tiles in this area.

# %% [markdown]
# ## **Tiling plot function**

# %%
def plot_sky_circle(x, y, radius, alpha=0.2, color=None):
    theta = np.linspace(0, 2*np.pi, 50)
    xx = x + np.cos(np.radians(y))*radius*np.cos(theta)
    yy = y + radius*np.sin(theta)
    plt.fill(xx, yy, alpha=alpha, color=color)

def plot_tile(ra, dec, color=None, alpha=0.2):
    tile_radius = desimodel.focalplane.get_tile_radius_deg()
    plot_sky_circle(ra, dec, tile_radius, color=color)

def plot_tiles(tiles):
    for i in range(len(tiles)):
        plot_tile(tiles['RA'][i], tiles['DEC'][i])
    plt.xlabel('RA [degrees]')
    plt.ylabel('DEC [degrees]')

# %%
plt.figure(figsize=(10,8))
plt.title('Tiling selection by area')
plot_tiles(tiles)

# %%
ii_dark_1 = (tiles['PROGRAM']=='DARK') & (tiles['PASS']==1)
ii_dark_2 = (tiles['PROGRAM']=='DARK') & (tiles['PASS']==2)
ii_dark_3 = (tiles['PROGRAM']=='DARK') & (tiles['PASS']==3)
ii_dark_4 = (tiles['PROGRAM']=='DARK') & (tiles['PASS']==4)
layers = [ii_dark_1, ii_dark_2, ii_dark_3, ii_dark_4]

ii_dark_1.sum(), ii_dark_2.sum(), ii_dark_3.sum(), ii_dark_4.sum()
# Out:
# (14, 12, 12, 12)

# %% [markdown]
# Now lets see which of those tiles are covered on the first year and save the exposures.fits file for this area.

# %% [markdown]
# ### **Reducing by Y1 footprint**

# %%
w=np.isin(tiles['TILEID'], year1['TILEID'])
tiles=tiles[w]
print('There are {} tiles in this small area from Y1 footprint.'.format(len(tiles)))
tiles.write(outdir+'/reduced_tiles.fits',overwrite=True)
# Out:
# There are 24 tiles in this small area from Y1 footprint.

# %%
plt.figure(figsize=(10,8))
plt.title('Tiling selection covered on the DESI Y1')
plot_tiles(tiles)

# %%
expfolder=os.path.join(outdir, 'exposures')
os.makedirs(expfolder,exist_ok=True)
expfile=os.path.join(expfolder, 'exposuresY1.fits')
if os.path.exists(expfile):
    print('exposures file already done; skipping')
    year1=Table(fitsio.read(expfile))
else:
    print('Writing exposure file in {}'.format(expfile))
    w=np.isin(year1['TILEID'], tiles['TILEID'])
    year1=year1[w]
    year1.write(expfile)
# Out:
# exposures file already done; skipping

# %%
# !ls
# Out:
# exposures  fba-reobs	  mtl-reobs.fits      sky.fits	       zcat.fits
# fba	   mtl-dark.fits  reduced_tiles.fits  truth-dark.fits

# %% [markdown]
# ## **Layers**
# > Layer is a set of tiles that cover the whole footprint, and there should be 4 dark-time layers and 1 gray-time layers

# %%
ii_dark_1 = (tiles['PROGRAM']=='DARK') & (tiles['PASS']==1)
ii_dark_2 = (tiles['PROGRAM']=='DARK') & (tiles['PASS']==2)
ii_dark_3 = (tiles['PROGRAM']=='DARK') & (tiles['PASS']==3)
ii_dark_4 = (tiles['PROGRAM']=='DARK') & (tiles['PASS']==4)
layers = [ii_dark_1, ii_dark_2, ii_dark_3, ii_dark_4]

ii_dark_1.sum(), ii_dark_2.sum(), ii_dark_3.sum(), ii_dark_4.sum()
# Out:
# (14, 1, 2, 7)

# %%
def plot_layers(tiles, layers):
    
    for i in np.arange(4):
        
        # plt.figure(figsize=(5,5))
        
        ii = layers[i]
        tiles_layer = tiles[ii]
        colors = ['k', 'r', 'g', 'b', 'y', 'm']
                
        for j in range(len(tiles_layer)):
            plot_tile(tiles_layer['RA'][j], tiles_layer['DEC'][j], color=colors[i])
            
        plt.xlabel('RA [degrees]')
        plt.ylabel('DEC [degrees]')
        
        # plt.title('Layer ' + str(i+1))
            
    return

# %%
plt.figure(figsize=(10,8))
plt.title('Tiles divided into layers')
plot_layers(tiles, layers)

# %% [markdown]
# # **Reducing a whole footprint mock target selection run to match our footprint**

# %% [markdown]
# In this step we will select the targets that match the Y1 footprint from a whole footprint mock target selection catalog.
#
# > All targets
#
# ```
# /project/projectdirs/desi/users/alxogm/desi/select_mock_targets/dark_all_sky_nospec/
# ```
#
# > Only QSOs
#
# ```
# /project/projectdirs/desi/users/alxogm/desi/select_mock_targets/onlyqso_all_sky_nospec
# ```
#
# this is a run of `select_mock_targets` run of only qsos and stars.

# %%
def reducefile(file, tiles, outdir='./', nside=16):
    
    tilepixels=desimodel.footprint.tiles2pix(nside=nside, tiles=tiles)
    print('Getting {} footprint pixels from {}'.format(tilepixels.size, file))
    pixels=Table(fitsio.read(file, columns=['HPXPIXEL']))
    whichtargets=np.isin(pixels['HPXPIXEL'], tilepixels)
    rows=np.where(whichtargets==True)[0]
    
    filename=os.path.split(file)[-1]
    print('Reducing data')
    reduced = Table(fitsio.read(file,rows=rows))
    name=os.path.join(outdir, filename)
    print(f'Writing reduced file {name}')
    reduced.write(name, overwrite=True)
    print('DONE')
    del reduced
    
    return rows

# %%
def make_reducefile(filelist, nside=16):

    do_reducefiles = False
    do_mtl=False

    if not os.path.exists(mtlfile):
        do_mtl=True

    for filename in filelist:
        if not os.path.exists(os.path.join(outdir, filename)):
            do_reducefiles = True
            break

    if not do_reducefiles:
        print('Already reduced files; skipping')
    else:
        print('Reducing files.')
        sky = reducefile(skyfile, tiles, outdir, nside=nside)

        if not do_mtl:
            rows = reducefile(mtlfile, tiles, outdir, nside=nside)
        else:
            print('MTL file does not exist in input path, generating reduced mtl for this run')
            rows = reducefile(targetfile, tiles, outdir, nside=nside)
            targets=fitsio.read(os.path.join(outdir,'targets-dark.fits'))
            mtl = mtl.make_mtl(targets, obscon='DARK')
            mtlname=os.path.join(outdir,'mtl-dark.fits')
            mtl.meta['EXTNAME'] = 'MTL'
            mtl.write(mtlname, overwrite=True, format='fits')

        print('Reducing truth file')   
        reduced_truth = Table(fitsio.read(truthfile, rows=rows)) 
        # Truth file doesn't contain a HPXPIXEL column but its aranged the same way as mtl
        reduced_truth.write(os.path.join(outdir,'truth-dark.fits'), overwrite=True)
        #del reduced_truth
        print('DONE')
        
        return

# %%
mockpath='/global/cfs/projectdirs/desi/mocks/lya_forest/develop/london/smt/nospectra/onlyqso_all_sky_nospec/' 
# Only QSO catalog
truthfile=os.path.join(mockpath,'truth-dark.fits')
mtlfile=os.path.join(mockpath,'mtl-dark.fits')
targetfile=os.path.join(mockpath,'targets-dark.fits')
skyfile=os.path.join(mockpath,'sky.fits')
fbadir=os.path.join(mockpath,'out_fba')

# %%
filelist = ['truth-dark.fits', 'mtl-dark.fits', 'sky.fits']
make_reducefile(filelist, nside=16)
# Out:
# Already reduced files; skipping

# %% [markdown]
# * **The reduce file functions does not work for nside != 16**
# > It would be useful to work with maps with higer resolution later

# %%
# !ls
# Out:
# exposures  fba-reobs	  mtl-reobs.fits      sky.fits	       zcat.fits
# fba	   mtl-dark.fits  reduced_tiles.fits  truth-dark.fits

# %% [markdown]
# ### **QSOs vs stars**

# %%
targets = Table.read('mtl-dark.fits')

# %%
ii = targets['DESI_TARGET'] == 4
QSOs = targets[ii]

ii = targets['DESI_TARGET'] != 4
stars = targets[ii]

# %%
ratio_qso = 100*len(QSOs)/len(targets)
ratio_stars = 100*len(stars)/len(targets)
print("Ratio of QSOs in the MTL: %.1f%%" % ratio_qso)
print("Ratio of stars in the MTL: %.1f%%" % ratio_stars)
# Out:
# Ratio of QSOs in the MTL: 14.0%
# Ratio of stars in the MTL: 86.0%

# %% [markdown]
# # **Running the fiber assignment code to  only QSOs and stars**

# %%
truth_reduced=os.path.join(outdir,'truth-dark.fits')
mtl_reduced=os.path.join(outdir,'mtl-dark.fits')
sky_reduced=os.path.join(outdir,'sky.fits')
tiles_reduced=os.path.join(outdir,'reduced_tiles.fits')
fbadir=os.path.join(outdir,'fba')

# %% [markdown]
# * By default, fiberassign uses the real focalplane geometry and properties at the current time. During operations, if a fiber broke yesterday and you run fiberassign today with an up-to-date desimodel data checkout, then that fiber will not be assigned. For this tutorial, we will run fiberassign with a rundate set to a time in the past before the start of commissioning. This will give us a nominal focalplane layout with all positioners working.

# %%
assign_date= "2020-01-01T00:00:00"

# %%
# Run fiberassign
cmd = 'fiberassign --overwrite --mtl {mtl} --sky {sky}'
cmd += ' --rundate {}'.format(assign_date)
cmd += ' --footprint {tiles}'
cmd += ' --outdir {out}'
cmd = cmd.format(mtl=mtl_reduced, sky=sky_reduced, tiles=tiles_reduced, out=fbadir)

# %%
print('RUNNING: '+cmd)
try:
    results = subprocess.check_output(cmd.split(), stderr=subprocess.STDOUT)
    print(results.decode())
    print('--- SUCCESS ---')
except subprocess.CalledProcessError as ex:
    print('--- ERROR {} ---'.format(ex.returncode))
    print(ex.output.decode())
    raise ex
# Out:
# RUNNING: fiberassign --overwrite --mtl /global/cscratch1/sd/andsouza/desi/priority_tests/mtl-dark.fits --sky /global/cscratch1/sd/andsouza/desi/priority_tests/sky.fits --rundate 2020-01-01T00:00:00 --footprint /global/cscratch1/sd/andsouza/desi/priority_tests/reduced_tiles.fits --outdir /global/cscratch1/sd/andsouza/desi/priority_tests/fba
# INFO: Loaded focalplane for time stamp 2020-01-01 00:00:00
# INFO: Focalplane has 0 fibers that are stuck / broken
# INFO: Target file /global/cscratch1/sd/andsouza/desi/priority_tests/mtl-dark.fits has 281327 rows.  Reading in chunks of 1000000
# INFO: Read target file /global/cscratch1/sd/andsouza/desi/priority_tests/mtl-dark.fits:  0.57 seconds (1 calls)
# INFO: Target file /global/cscratch1/sd/andsouza/desi/priority_tests/sky.fits has 311296 rows.  Reading in chunks of 1000000
# INFO: Read target file /global/cscratch1/sd/andsouza/desi/priority_tests/sky.fits:  0.66 seconds (1 calls)
# INFO: Building target tree:  0.17 seconds (1 calls)
# INFO: Computing targets available to all tile / locations:  0.90 seconds (1 calls)
# INFO: Computing tile / locations available to all objects:  0.31 seconds (1 calls)
# INFO: Assignment constructor project targets:  0.56 seconds (1 calls)
# INFO: assign unused science:  considering 5000 locations of positioner type "POS"
# INFO: assign unused science:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign science targets to unused locations:  2.58 seconds (1 calls)
# INFO: redist:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Redistribute science targets:  0.22 seconds (1 calls)
# INFO: assign unused standard:  considering 5000 locations of positioner type "POS"
# INFO: assign unused standard:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign up to 10 standard targets per petal to unused locations:  0.07 seconds (1 calls)
# INFO: assign unused sky:  considering 5000 locations of positioner type "POS"
# INFO: assign unused sky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign up to 40 sky targets per petal to unused locations:  0.60 seconds (1 calls)
# INFO: assign unused suppsky:  considering 5000 locations of positioner type "POS"
# INFO: assign unused suppsky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign up to 40 suppsky targets per petal to unused locations:  0.05 seconds (1 calls)
# INFO: assign force standard:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Force assignment of 10 standard targets per petal:  0.19 seconds (1 calls)
# INFO: assign force sky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Force assignment of 40 sky targets per petal:  0.35 seconds (1 calls)
# INFO: assign force suppsky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Force assignment of 40 suppsky targets per petal:  0.18 seconds (1 calls)
# INFO: assign unused science:  considering 5000 locations of positioner type "POS"
# INFO: assign unused science:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign science targets to unused locations:  0.13 seconds (1 calls)
# INFO: assign unused standard:  considering 5000 locations of positioner type "POS"
# INFO: assign unused standard:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign standard targets to unused locations:  0.11 seconds (1 calls)
# INFO: assign unused sky:  considering 5000 locations of positioner type "POS"
# INFO: assign unused sky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign sky targets to unused locations:  1.35 seconds (1 calls)
# INFO: assign unused suppsky:  considering 5000 locations of positioner type "POS"
# INFO: assign unused suppsky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign suppsky targets to unused locations:  0.03 seconds (1 calls)
# INFO: assign unused safe:  considering 5000 locations of positioner type "POS"
# INFO: assign unused safe:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign safe targets to unused locations:  0.03 seconds (1 calls)
# INFO: assign unused sky:  considering 20 locations of positioner type "ETC"
# INFO: assign unused sky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign sky targets to unused locations:  0.01 seconds (1 calls)
# INFO: assign unused suppsky:  considering 20 locations of positioner type "ETC"
# INFO: assign unused suppsky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign suppsky targets to unused locations:  0.00 seconds (1 calls)
# INFO: assign unused safe:  considering 20 locations of positioner type "ETC"
# INFO: assign unused safe:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign safe targets to unused locations:  0.00 seconds (1 calls)
# INFO: Writing tile 11053
# INFO: Writing tile 11072
# INFO: Writing tile 11073
# INFO: Writing tile 11074
# INFO: Writing tile 11075
# INFO: Writing tile 11092
# INFO: Writing tile 11093
# INFO: Writing tile 11094
# INFO: Writing tile 11095
# INFO: Writing tile 11145
# INFO: Writing tile 11146
# INFO: Writing tile 11147
# INFO: Writing tile 11163
# INFO: Writing tile 11164
# INFO: Writing tile 16837
# INFO: Writing tile 22599
# INFO: Writing tile 22687
# INFO: Writing tile 28360
# INFO: Writing tile 28361
# INFO: Writing tile 28378
# INFO: Writing tile 28433
# INFO: Writing tile 28449
# INFO: Writing tile 28450
# INFO: Writing tile 28451
# INFO: Write output files:  4.24 seconds (1 calls)
# INFO: Global timer: Assignment ctor: project targets:  0.56 seconds (1 calls)
# INFO: Global timer: Assignment ctor: total:  0.56 seconds (1 calls)
# INFO: Global timer: force sky: local tile availability:  0.24 seconds (24 calls)
# INFO: Global timer: force sky: local tile compute science assignment:  0.06 seconds (24 calls)
# INFO: Global timer: force sky: total:  0.35 seconds (1 calls)
# INFO: Global timer: force standard: local tile availability:  0.08 seconds (24 calls)
# INFO: Global timer: force standard: local tile compute science assignment:  0.06 seconds (24 calls)
# INFO: Global timer: force standard: total:  0.19 seconds (1 calls)
# INFO: Global timer: force suppsky: local tile availability:  0.07 seconds (24 calls)
# INFO: Global timer: force suppsky: local tile compute science assignment:  0.06 seconds (24 calls)
# INFO: Global timer: force suppsky: total:  0.18 seconds (1 calls)
# INFO: Global timer: redistribute science: total:  0.22 seconds (1 calls)
# INFO: Global timer: run_assign_full calculation:  11.73 seconds (1 calls)
# INFO: Global timer: run_assign_full write output:  4.24 seconds (1 calls)
# INFO: Global timer: unused safe: local tile availability:  0.03 seconds (48 calls)
# INFO: Global timer: unused safe: total:  0.03 seconds (2 calls)
# INFO: Global timer: unused science: local tile availability:  0.41 seconds (48 calls)
# INFO: Global timer: unused science: total:  2.71 seconds (2 calls)
# INFO: Global timer: unused sky: local tile availability:  0.28 seconds (72 calls)
# INFO: Global timer: unused sky: total:  1.96 seconds (3 calls)
# INFO: Global timer: unused standard: local tile availability:  0.11 seconds (48 calls)
# INFO: Global timer: unused standard: total:  0.17 seconds (2 calls)
# INFO: Global timer: unused suppsky: local tile availability:  0.08 seconds (72 calls)
# INFO: Global timer: unused suppsky: total:  0.08 seconds (3 calls)
# INFO: Read /global/cscratch1/sd/andsouza/desi/priority_tests/mtl-dark.fits into shared memory:  1.03 seconds (1 calls)
# INFO: Read /global/cscratch1/sd/andsouza/desi/priority_tests/sky.fits into shared memory:  1.18 seconds (1 calls)
# INFO: Read /global/cscratch1/sd/andsouza/desi/priority_tests/sky.fits into shared memory:  1.18 seconds (1 calls)
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011164.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011073.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011145.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011146.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011092.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-016837.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-028433.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011072.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011147.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011095.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-028378.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-028449.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-028451.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011094.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-028361.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011093.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-028360.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-022599.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011075.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011163.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-022687.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-028450.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011053.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fba-011074.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011053.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011074.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011145.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-016837.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-028433.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-028449.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011164.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-022599.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011094.fits
# ERROR: REF_EPOCH not set, using 2015.5
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-022687.fits
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-028450.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-028360.fits
# ERROR: REF_EPOCH not set, using 2015.5
# ERROR: REF_EPOCH not set, using 2015.5
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011092.fits
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011072.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011075.fits
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011146.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011163.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-028451.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011095.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-028378.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011073.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011093.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-011147.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba/fiberassign-028361.fits
#
# --- SUCCESS ---

# %%
# !ls fba
# Out:
# fba-011053.fits  fba-022687.fits	  fiberassign-011095.fits
# fba-011072.fits  fba-028360.fits	  fiberassign-011145.fits
# fba-011073.fits  fba-028361.fits	  fiberassign-011146.fits
# fba-011074.fits  fba-028378.fits	  fiberassign-011147.fits
# fba-011075.fits  fba-028433.fits	  fiberassign-011163.fits
# fba-011092.fits  fba-028449.fits	  fiberassign-011164.fits
# fba-011093.fits  fba-028450.fits	  fiberassign-016837.fits
# fba-011094.fits  fba-028451.fits	  fiberassign-022599.fits
# fba-011095.fits  fiberassign-011053.fits  fiberassign-022687.fits
# fba-011145.fits  fiberassign-011072.fits  fiberassign-028360.fits
# fba-011146.fits  fiberassign-011073.fits  fiberassign-028361.fits
# fba-011147.fits  fiberassign-011074.fits  fiberassign-028378.fits
# fba-011163.fits  fiberassign-011075.fits  fiberassign-028433.fits
# fba-011164.fits  fiberassign-011092.fits  fiberassign-028449.fits
# fba-016837.fits  fiberassign-011093.fits  fiberassign-028450.fits
# fba-022599.fits  fiberassign-011094.fits  fiberassign-028451.fits

# %% [markdown]
# ## **Fiber assignment distribution to targets**
#
# * How many were targets covered by fibers
# * How many were targets really assigned to one?

# %%
def get_assigned_covered(targets, tiles, outdir):
    assigned_ids = list()
    covered_ids = list()
    for tileid in tiles['TILEID']:
        fafile = '{}/fiberassign-{:06d}.fits'.format(outdir, tileid)
        assignments = Table.read(fafile, 'FIBERASSIGN')
        assigned_ids.extend(assignments['TARGETID'])

        #- Note: a single target could be covered by more than one fiber on the same tile, 
        # but it still can only be assigned once, so use np.unique() per tile
        # to not double count those cases
        potential = Table.read(fafile, 'POTENTIAL_ASSIGNMENTS')
        # a table of what targets were covered by what fibers
        covered_ids.extend(np.unique(potential['TARGETID']))

    #- Trim to just science targets (i.e. not SKY, not non-science STDSTAR)
    assigned_ids = np.array(assigned_ids)
    ii = np.in1d(assigned_ids, targets['TARGETID'])
    assigned_ids = assigned_ids[ii]

    covered_ids = np.array(covered_ids)
    ii = np.in1d(covered_ids, targets['TARGETID'])
    covered_ids = covered_ids[ii]

    return assigned_ids, covered_ids

# %%
#- Do a bit of counting magic to include targets that were never assigned or covered
def count_coverage(targets, ids):
    c = Counter(ids)
    c.update(targets['TARGETID'])
    count = np.array(list(c.values())) - 1
    return count

# %%
def plot_counting_assign(targets, tiles, outdir):
    
    assigned_ids, covered_ids = get_assigned_covered(targets, tiles, outdir)
    assigned_count = count_coverage(targets, assigned_ids)
    covered_count = count_coverage(targets, covered_ids)
    
    plt.figure(figsize=(6,8))

    plt.subplot(211)
    plt.hist(assigned_count, 5, (-0.5, 4.5), rwidth=0.8)
    plt.xticks(np.arange(0,5))
    plt.xlabel('number of times assigned')

    plt.subplot(212)
    plt.hist(covered_count, 5, (-0.5, 4.5), rwidth=0.8)
    plt.xticks(np.arange(0,5))
    plt.xlabel('number of times covered')

    plt.tight_layout()
    
    return

# %%
def plot_fiber_assign(targets, tiles, outdir):
    
    assignments = list()
    for tileid in tiles['TILEID']:
        fafile = '{}/fiberassign-{:06d}.fits'.format(outdir, tileid)
        assignments.append(Table.read(fafile, hdu=1))

    assigned_targetids = np.concatenate([tmp['TARGETID'] for tmp in assignments])
    isAssigned = np.in1d(targets['TARGETID'], assigned_targetids)
    
    plt.subplot(131)
    plt.plot(targets['RA'][isAssigned], targets['DEC'][isAssigned], 'k,')
    plt.title('Targets assigned to fibers')
    plt.xlabel('RA [deg]')
    plt.ylabel('DEC [deg]')
    
    potential_targets = list()
    for tileid in tiles['TILEID']:
        fafile = '{}/fiberassign-{:06d}.fits'.format(outdir, tileid)
        potential_targets.append(Table.read(fafile, hdu=4))

    potential_targetids = np.concatenate([tmp['TARGETID'] for tmp in potential_targets])
    potential_targetids = np.unique(potential_targetids)  

    ii = np.in1d(potential_targetids, assigned_targetids, invert=True)
    potential_unassigned = potential_targetids[ii]

    notAssigned = np.in1d(targets['TARGETID'], potential_unassigned)

    plt.subplot(132)
    plt.plot(targets['RA'][notAssigned], targets['DEC'][notAssigned], 'k,')
    plt.title('Potential targets not assigned to fibers')
    plt.xlabel('RA [deg]')
    # plt.ylabel('DEC [deg]')
    
    notPotential = np.in1d(targets['TARGETID'], np.concatenate([assigned_targetids, potential_unassigned]), 
                       invert=True)

    plt.subplot(133)
    plt.plot(targets['RA'][notPotential], targets['DEC'][notPotential], 'k,')
    plt.title('Unavailable targets')
    plt.xlabel('RA [deg]')
    # plt.ylabel('DEC [deg]')  
    
    n_isAssigned = np.count_nonzero(isAssigned)
    n_notAssigned = np.count_nonzero(notAssigned)
    n_notPotential = np.count_nonzero(notPotential)
    
    n_targets = len(targets['TARGETID'])
    n_fibers = int(0.9 * len(tiles) * 5000)  
    # 10% of fibers are reserved for std and sky calibrators

    
    assert n_isAssigned + n_notAssigned + n_notPotential == n_targets
    
    print('Total of targets:                 ', n_targets)
    print('Targets assigned:                 ', n_isAssigned)
    print('Estimation of counting fibers:    ', n_fibers)
    print('Potential targets not assigned:   ', n_notAssigned)
    print('Unavailable targets:              ', n_notPotential)
    print()
    
    print('Percentage over the total number of targets')
    print('Targets assigned:                 %.2f%%' % (100*n_isAssigned/n_targets))
    print('Potential targets not assigned:   %.2f%%' % (100*n_notAssigned/n_targets))
    print('Unavailable targets:              %.2f%%' % (100*n_notPotential/n_targets))
    print()
    
    print('Targets assigned/Counting fibers: %.2f%%' % (100*n_isAssigned/n_fibers))
    
    return

# %%
def cross_assign_cover(targets, tiles, outdir):

    assigned_ids, covered_ids = get_assigned_covered(targets, tiles, outdir)

    count_assigned = Counter(assigned_ids)
    count_covered = Counter(covered_ids)    
    
    n_max, m_max = 0, 0
    
    for tid in targets['TARGETID']:
        n = count_assigned[tid]
        m = count_covered[tid]
        if n > n_max: n_max = n
        if m > m_max: m_max = m
            
    n2d = np.ones((n_max+1, m_max+1), dtype=int)
    
    for tid in targets['TARGETID']:
        n = count_assigned[tid]
        m = count_covered[tid]
        n2d[n,m] += 1    
            
    import seaborn as sns
    from matplotlib.colors import LogNorm
    
    log_norm = LogNorm(vmin=n2d.min().min(), vmax=n2d.max().max())
    cbar_ticks = [math.pow(10, i) for i in range(math.floor(math.log10(n2d.min().min())), 1+math.ceil(math.log10(n2d.max().max())))]

    ax = sns.heatmap(n2d, cmap="YlGnBu", norm=log_norm, cbar_kws={"ticks": cbar_ticks})
    plt.xlabel('Number of times Covered')
    plt.ylabel('Number of times Assigned')

# %% [markdown]
# ## **Getting only QSOs**

# %%
targets = Table.read(mtl_reduced)
ii = targets['DESI_TARGET'] == 4
targets = targets[ii]

tiles = Table.read(tiles_reduced)
fbadir=os.path.join(outdir,'fba')

# %%
plot_counting_assign(targets, tiles, fbadir)

# %%
plt.figure(figsize=(18,6))
plot_fiber_assign(targets, tiles, fbadir)
# Out:
# Total of targets:                  39355
# Targets assigned:                  15368
# Estimation of counting fibers:     108000
# Potential targets not assigned:    1504
# Unavailable targets:               22483
#
# Percentage over the total number of targets
# Targets assigned:                 39.05%
# Potential targets not assigned:   3.82%
# Unavailable targets:              57.13%
#
# Targets assigned/Counting fibers: 14.23%

# %%
cross_assign_cover(targets, tiles, fbadir)

# %% [markdown]
# # **Create a first zcatalog as it is done in multipass**
#
# * The git repo of the multipass code is on this [link](https://github.com/forero/multipass/blob/42c9d13c5ceb9a61c362e2f8117acb697fc29735/run_multilayer.py#L342-L346).
# * The function that create the redshift catalog is the [desisim/quickcat.py](https://github.com/desihub/desisim/blob/fddf9c808400918edd55fec9a17b12e066293295/py/desisim/quickcat.py#L563).
#
# Code for quickly generating an output zcatalog given fiber assignment tiles, a truth catalog, and optionally a previous zcatalog.

# %% [markdown]
# > **quickcat(tilefiles, targets, truth, zcat=None, obsconditions=None, perfect=False)**
#
#     Generates quick output zcatalog
#     Args:
#         tilefiles : list of fiberassign tile files that were observed
#         targets : astropy Table of targets
#         truth : astropy Table of input truth with columns TARGETID, TRUEZ, and TRUETYPE
#         zcat (optional): input zcatalog Table from previous observations
#         obsconditions (optional): Table or ndarray with observing conditions from surveysim
#         perfect (optional): if True, treat spectro pipeline as perfect with input=output,
#             otherwise add noise and zwarn!=0 flags
#     Returns:
#         zcatalog astropy Table based upon input truth, plus ZERR, ZWARN,
#         NUMOBS, and TYPE columns

# %% [markdown]
# * All the FiberAssign outputs

# %%
fba_files = np.sort(glob.glob(os.path.join(fbadir,"fiberassign*.fits")))

# %%
zcat = quickcat(fba_files, Table.read(mtl_reduced), Table.read(truth_reduced), perfect=True)
# Out:
# INFO:quickcat.py:585:quickcat: Fri Apr 10 11:16:39 2020 QC Reading 24 tiles
# INFO:quickcat.py:629:quickcat: Fri Apr 10 11:16:43 2020 QC Trimming truth to just observed targets
# INFO:quickcat.py:636:quickcat: Fri Apr 10 11:16:43 2020 QC Constructing new redshift catalog
# INFO:quickcat.py:648:quickcat: Fri Apr 10 11:16:43 2020 QC Adding ZERR and ZWARN
# INFO:quickcat.py:666:quickcat: Fri Apr 10 11:16:43 2020 QC Adding NUMOBS column
# INFO:quickcat.py:672:quickcat: Fri Apr 10 11:16:43 2020 QC Merging previous zcat
# INFO:quickcat.py:719:quickcat: Fri Apr 10 11:16:43 2020 QC done

# %%
zcat[:5]
# Out:
# <Table length=5>
#      TARGETID      BRICKNAME SPECTYPE     Z       ZERR  ZWARN NUMOBS
#       int64           str8    str10    float32  float32 int32 int32
# ------------------ --------- -------- --------- ------- ----- ------
# 288230383395275605                QSO  2.313405     0.0     0      1
# 288230383395275606                QSO    2.5355     0.0     0      1
# 288230383395275610                QSO 2.1095347     0.0     0      1
# 288230383395275617                QSO 2.3436482     0.0     0      1
# 288230383395275688                QSO 2.4378078     0.0     0      1

# %% [markdown]
# ### **Generating some targets with warning redshift**
# > Only to simulate (there is no realistic prediction yet): 10% of the sample

# %%
import random
ii = random.sample(range(0, len(zcat)), int(0.1*len(zcat)))
zcat['ZWARN'][ii] = 1

# %%
zcatfile = os.path.join(outdir, 'zcat.fits')

# %%
zcat.write(zcatfile, overwrite=True)

# %% [markdown]
# # **Quasar re-observation**

# %% [markdown]
# > Getting an external input to update the information regarding priorities before each call to fiber assignment
# * modify priority set between calls of fiber assignment based for example on the agreement to redshift fitters

# %%
from desitarget import mtl

# %% [markdown]
# ## **The mtl.make_mtl function**
# * Look at this function at [desitarget/mtl.py](https://github.com/desihub/desitarget/blob/c56191a86625e09a2237c641351ac9b7c663b185/py/desitarget/mtl.py#L19)
# * It adds NUMOBS_MORE, PRIORITY, and OBSCONDITIONS columns to a targets table
# * Inputs: make_mtl(targets, obscon, zcat=None, trim=False, scnd=None)
#
# > Before this moment, the `PRIORITY` is used only to separate science targets from sky and standard stars in the mtl file, giving to the first ones more priority during the fiber assignment.

# %% [markdown]
# > **def make_mtl(targets, obscon, zcat=None, trim=False, scnd=None)**:
#
#     Adds NUMOBS_MORE, PRIORITY, and OBSCONDITIONS columns to a targets table.
#     Parameters
#     ----------
#     targets : :class:`~numpy.array` or `~astropy.table.Table`
#         A numpy rec array or astropy Table with at least the columns
#         ``TARGETID``, ``DESI_TARGET``, ``NUMOBS_INIT``, ``PRIORITY_INIT``.
#         or the corresponding columns for SV or commissioning.
#     zcat : :class:`~astropy.table.Table`, optional
#         Redshift catalog table with columns ``TARGETID``, ``NUMOBS``, ``Z``,
#         ``ZWARN``.
#     Returns
#     -------
#     :class:`~astropy.table.Table`
#         MTL Table with targets columns plus:
#         * NUMOBS_MORE    - number of additional observations requested
#         * PRIORITY       - target priority (larger number = higher priority)

# %%
mtl_reobs = mtl.make_mtl(Table.read(mtl_reduced), 'DARK', zcat=zcat)
# Out:
# INFO:mtl.py:161:make_mtl: 65267 of 281327 targets have priority zero, setting N_obs=0.
# INFO:mtl.py:197:make_mtl: Done...t=0.5s

# %% [markdown]
# ## **Check the make_mtl output**

# %%
import pandas as pd
reobs_pd = pd.DataFrame()
reobs_pd['TARGETID'] = mtl_reobs['TARGETID']
reobs_pd['DESI_TARGET'] = mtl_reobs['DESI_TARGET']
reobs_pd['NUMOBS'] = np.zeros(len(mtl_reobs))
reobs_pd['PRIORITY_INIT'] = mtl_reobs['PRIORITY_INIT']
reobs_pd['Z'] = -np.ones(len(mtl_reobs))
reobs_pd['ZWARN'] = np.zeros(len(mtl_reobs))
reobs_pd['NUMOBS_MORE'] = mtl_reobs['NUMOBS_MORE']
reobs_pd['PRIORITY'] = mtl_reobs['PRIORITY']

# %% [markdown]
# ### **Adding info about targets observed at the first running**

# %%
w = isin(reobs_pd['TARGETID'], zcat['TARGETID'])
reobs_pd['Z'][w] = zcat['Z']
reobs_pd['ZWARN'][w] = zcat['ZWARN']
reobs_pd['NUMOBS'][w] = zcat['NUMOBS']
# Out:
# /global/common/software/desi/cori/desiconda/20190804-1.3.0-spec/conda/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /global/common/software/desi/cori/desiconda/20190804-1.3.0-spec/conda/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /global/common/software/desi/cori/desiconda/20190804-1.3.0-spec/conda/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ii = (reobs_pd['DESI_TARGET'] == 4) & (reobs_pd['Z'] != -1)
sns.distplot(reobs_pd['Z'][ii], kde=True)
plt.title('All quasars with known redshift')
plt.xlabel('Redshift z')
# Out:
# Text(0.5,0,'Redshift z')

# %%
desi_mask['QSO'].priorities
# Out:
# {'UNOBS': 3400,
#  'MORE_ZGOOD': 3500,
#  'DONE': 2,
#  'OBS': 1,
#  'DONOTOBSERVE': 0,
#  'MORE_ZWARN': 3400}

# %%
ii = reobs_pd['DESI_TARGET'] == 4
reobs_pd[ii].groupby(['PRIORITY', 'ZWARN', 'NUMOBS', 'NUMOBS_MORE'])['Z'].describe()
# Out:
#                                      count      mean       std       min  \
# PRIORITY ZWARN NUMOBS NUMOBS_MORE
# 2        0.0   1.0    0             5023.0  1.387967  0.522628  0.101982
#                2.0    0             2180.0  1.378319  0.530854  0.135646
#                3.0    0              655.0  1.377642  0.529313  0.103528
#                4.0    0              302.0  1.671897  0.756329  0.113234
#          1.0   4.0    0               85.0  1.709924  0.726736  0.190637
# 3400     0.0   0.0    4            23987.0 -1.000000  0.000000 -1.000000
#          1.0   1.0    3             2548.0  1.710554  0.732088  0.104559
#                2.0    2             1137.0  1.727067  0.728254  0.111979
#                3.0    1              389.0  1.779303  0.728720  0.159800
# 3500     0.0   1.0    3             1927.0  2.573893  0.347602  2.150320
#                2.0    2              832.0  2.607211  0.368422  2.150060
#                3.0    1              290.0  2.615914  0.364855  2.150344
#
#                                         25%       50%       75%       max
# PRIORITY ZWARN NUMOBS NUMOBS_MORE
# 2        0.0   1.0    0            1.012088  1.462274  1.836710  2.149732
#                2.0    0            1.019187  1.447350  1.835786  2.149530
#                3.0    0            1.011043  1.434185  1.817495  2.149791
#                4.0    0            1.056805  1.688466  2.240489  3.779948
#          1.0   4.0    0            1.149823  1.735025  2.269923  3.028451
# 3400     0.0   0.0    4           -1.000000 -1.000000 -1.000000 -1.000000
#          1.0   1.0    3            1.160083  1.760347  2.227150  3.760604
#                2.0    2            1.217896  1.751250  2.237470  3.774992
#                3.0    1            1.246756  1.830414  2.297830  3.655854
# 3500     0.0   1.0    3            2.295415  2.484232  2.775944  3.795638
#                2.0    2            2.314560  2.505175  2.807143  3.797181
#                3.0    1            2.312786  2.532235  2.830246  3.793410

# %%
ii = (reobs_pd['DESI_TARGET'] == 4) & (reobs_pd['PRIORITY'] == 2)
sns.distplot(reobs_pd['Z'][ii], kde=True)
plt.title('PRIORITY = 2 and STATUS = DONE')
plt.xlabel('Redshift z')
# Out:
# Text(0.5,0,'Redshift z')

# %%
ii = (reobs_pd['DESI_TARGET'] == 4) & (reobs_pd['PRIORITY'] == 3500)
sns.distplot(reobs_pd['Z'][ii])
plt.title('PRIORITY = 3500 and STATUS = MORE_ZGOOD')
plt.xlabel('Redshift z')
# Out:
# Text(0.5,0,'Redshift z')

# %% [markdown]
# ## **Re-run the fiber assignment after updated priorities**

# %%
mtlfile=os.path.join(outdir,'mtl-reobs.fits')

# %%
mtl_reobs.write(mtlfile, overwrite=True)

# %%
fbadir = os.path.join(outdir,'fba-reobs')

# %%
# Run fiberassign
cmd = 'fiberassign --overwrite --mtl {mtl} --sky {sky}'
cmd += ' --rundate {}'.format(assign_date)
cmd += ' --footprint {tiles}'
cmd += ' --outdir {out}'
cmd = cmd.format(mtl=mtlfile, sky=sky_reduced, tiles=tiles_reduced, out=fbadir)

# %%
print('RUNNING: '+cmd)
try:
    results = subprocess.check_output(cmd.split(), stderr=subprocess.STDOUT)
    print(results.decode())
    print('--- SUCCESS ---')
except subprocess.CalledProcessError as ex:
    print('--- ERROR {} ---'.format(ex.returncode))
    print(ex.output.decode())
    raise ex
# Out:
# RUNNING: fiberassign --overwrite --mtl /global/cscratch1/sd/andsouza/desi/priority_tests/mtl-reobs.fits --sky /global/cscratch1/sd/andsouza/desi/priority_tests/sky.fits --rundate 2020-01-01T00:00:00 --footprint /global/cscratch1/sd/andsouza/desi/priority_tests/reduced_tiles.fits --outdir /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs
# INFO: Loaded focalplane for time stamp 2020-01-01 00:00:00
# INFO: Focalplane has 0 fibers that are stuck / broken
# INFO: Target file /global/cscratch1/sd/andsouza/desi/priority_tests/mtl-reobs.fits has 281327 rows.  Reading in chunks of 1000000
# INFO: Read target file /global/cscratch1/sd/andsouza/desi/priority_tests/mtl-reobs.fits:  0.76 seconds (1 calls)
# INFO: Target file /global/cscratch1/sd/andsouza/desi/priority_tests/sky.fits has 311296 rows.  Reading in chunks of 1000000
# INFO: Read target file /global/cscratch1/sd/andsouza/desi/priority_tests/sky.fits:  1.03 seconds (1 calls)
# INFO: Building target tree:  0.22 seconds (1 calls)
# INFO: Computing targets available to all tile / locations:  1.15 seconds (1 calls)
# INFO: Computing tile / locations available to all objects:  0.40 seconds (1 calls)
# INFO: Assignment constructor project targets:  0.72 seconds (1 calls)
# INFO: assign unused science:  considering 5000 locations of positioner type "POS"
# INFO: assign unused science:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign science targets to unused locations:  1.15 seconds (1 calls)
# INFO: redist:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Redistribute science targets:  0.11 seconds (1 calls)
# INFO: assign unused standard:  considering 5000 locations of positioner type "POS"
# INFO: assign unused standard:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign up to 10 standard targets per petal to unused locations:  0.16 seconds (1 calls)
# INFO: assign unused sky:  considering 5000 locations of positioner type "POS"
# INFO: assign unused sky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign up to 40 sky targets per petal to unused locations:  0.81 seconds (1 calls)
# INFO: assign unused suppsky:  considering 5000 locations of positioner type "POS"
# INFO: assign unused suppsky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign up to 40 suppsky targets per petal to unused locations:  0.09 seconds (1 calls)
# INFO: assign force standard:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Force assignment of 10 standard targets per petal:  0.13 seconds (1 calls)
# INFO: assign force sky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Force assignment of 40 sky targets per petal:  0.22 seconds (1 calls)
# INFO: assign force suppsky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Force assignment of 40 suppsky targets per petal:  0.12 seconds (1 calls)
# INFO: assign unused science:  considering 5000 locations of positioner type "POS"
# INFO: assign unused science:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign science targets to unused locations:  0.17 seconds (1 calls)
# INFO: assign unused standard:  considering 5000 locations of positioner type "POS"
# INFO: assign unused standard:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign standard targets to unused locations:  0.31 seconds (1 calls)
# INFO: assign unused sky:  considering 5000 locations of positioner type "POS"
# INFO: assign unused sky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign sky targets to unused locations:  3.29 seconds (1 calls)
# INFO: assign unused suppsky:  considering 5000 locations of positioner type "POS"
# INFO: assign unused suppsky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign suppsky targets to unused locations:  0.04 seconds (1 calls)
# INFO: assign unused safe:  considering 5000 locations of positioner type "POS"
# INFO: assign unused safe:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign safe targets to unused locations:  0.04 seconds (1 calls)
# INFO: assign unused sky:  considering 20 locations of positioner type "ETC"
# INFO: assign unused sky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign sky targets to unused locations:  0.02 seconds (1 calls)
# INFO: assign unused suppsky:  considering 20 locations of positioner type "ETC"
# INFO: assign unused suppsky:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign suppsky targets to unused locations:  0.00 seconds (1 calls)
# INFO: assign unused safe:  considering 20 locations of positioner type "ETC"
# INFO: assign unused safe:  working on tiles -1 (index 0) to -1 (index 23)
# INFO: Assign safe targets to unused locations:  0.00 seconds (1 calls)
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011053.fits
# INFO: Writing tile 11053
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011072.fits
# INFO: Writing tile 11072
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011073.fits
# INFO: Writing tile 11073
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011074.fits
# INFO: Writing tile 11074
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011075.fits
# INFO: Writing tile 11075
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011092.fits
# INFO: Writing tile 11092
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011093.fits
# INFO: Writing tile 11093
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011094.fits
# INFO: Writing tile 11094
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011095.fits
# INFO: Writing tile 11095
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011145.fits
# INFO: Writing tile 11145
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011146.fits
# INFO: Writing tile 11146
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011147.fits
# INFO: Writing tile 11147
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011163.fits
# INFO: Writing tile 11163
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011164.fits
# INFO: Writing tile 11164
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-016837.fits
# INFO: Writing tile 16837
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-022599.fits
# INFO: Writing tile 22599
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-022687.fits
# INFO: Writing tile 22687
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028360.fits
# INFO: Writing tile 28360
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028361.fits
# INFO: Writing tile 28361
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028378.fits
# INFO: Writing tile 28378
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028433.fits
# INFO: Writing tile 28433
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028449.fits
# INFO: Writing tile 28449
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028450.fits
# INFO: Writing tile 28450
# WARNING: Overwriting /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028451.fits
# INFO: Writing tile 28451
# INFO: Write output files:  4.90 seconds (1 calls)
# INFO: Global timer: Assignment ctor: project targets:  0.72 seconds (1 calls)
# INFO: Global timer: Assignment ctor: total:  0.72 seconds (1 calls)
# INFO: Global timer: force sky: local tile availability:  0.15 seconds (24 calls)
# INFO: Global timer: force sky: local tile compute science assignment:  0.04 seconds (24 calls)
# INFO: Global timer: force sky: total:  0.22 seconds (1 calls)
# INFO: Global timer: force standard: local tile availability:  0.07 seconds (24 calls)
# INFO: Global timer: force standard: local tile compute science assignment:  0.04 seconds (24 calls)
# INFO: Global timer: force standard: total:  0.13 seconds (1 calls)
# INFO: Global timer: force suppsky: local tile availability:  0.05 seconds (24 calls)
# INFO: Global timer: force suppsky: local tile compute science assignment:  0.04 seconds (24 calls)
# INFO: Global timer: force suppsky: total:  0.12 seconds (1 calls)
# INFO: Global timer: redistribute science: total:  0.11 seconds (1 calls)
# INFO: Global timer: run_assign_full calculation:  14.58 seconds (1 calls)
# INFO: Global timer: run_assign_full write output:  4.90 seconds (1 calls)
# INFO: Global timer: unused safe: local tile availability:  0.04 seconds (48 calls)
# INFO: Global timer: unused safe: total:  0.04 seconds (2 calls)
# INFO: Global timer: unused science: local tile availability:  0.37 seconds (48 calls)
# INFO: Global timer: unused science: total:  1.31 seconds (2 calls)
# INFO: Global timer: unused sky: local tile availability:  0.68 seconds (72 calls)
# INFO: Global timer: unused sky: total:  4.12 seconds (3 calls)
# INFO: Global timer: unused standard: local tile availability:  0.24 seconds (48 calls)
# INFO: Global timer: unused standard: total:  0.47 seconds (2 calls)
# INFO: Global timer: unused suppsky: local tile availability:  0.13 seconds (72 calls)
# INFO: Global timer: unused suppsky: total:  0.13 seconds (3 calls)
# INFO: Read /global/cscratch1/sd/andsouza/desi/priority_tests/mtl-reobs.fits into shared memory:  1.18 seconds (1 calls)
# INFO: Read /global/cscratch1/sd/andsouza/desi/priority_tests/sky.fits into shared memory:  1.46 seconds (1 calls)
# INFO: Read /global/cscratch1/sd/andsouza/desi/priority_tests/sky.fits into shared memory:  1.38 seconds (1 calls)
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011073.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011164.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011145.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011146.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011092.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-016837.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028433.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011072.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011147.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011095.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028378.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028449.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028451.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011094.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028361.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011093.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028360.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-022599.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011075.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011163.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-022687.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-028450.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011053.fits
# INFO: Reading raw tile data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fba-011074.fits
# ERROR: REF_EPOCH not set, using 2015.5
# ERROR: REF_EPOCH not set, using 2015.5
# ERROR: REF_EPOCH not set, using 2015.5
# ERROR: REF_EPOCH not set, using 2015.5
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011095.fits
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011145.fits
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011073.fits
# ERROR: REF_EPOCH not set, using 2015.5
# ERROR: REF_EPOCH not set, using 2015.5
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011072.fits
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011092.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011093.fits
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-028451.fits
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011146.fits
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-028450.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011164.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-028449.fits
# ERROR: REF_EPOCH not set, using 2015.5
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-028360.fits
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-028378.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-022687.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-016837.fits
# ERROR: REF_EPOCH not set, using 2015.5
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011075.fits
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-028361.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011053.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011147.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011074.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011094.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-022599.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-028433.fits
# ERROR: REF_EPOCH not set, using 2015.5
# INFO: Writing new data /global/cscratch1/sd/andsouza/desi/priority_tests/fba-reobs/fiberassign-011163.fits
#
# --- SUCCESS ---

# %%
# !ls
# Out:
# exposures  fba-reobs	  mtl-reobs.fits      sky.fits	       zcat.fits
# fba	   mtl-dark.fits  reduced_tiles.fits  truth-dark.fits

# %% [markdown]
# ### **PRIORITY = 2**

# %%
ii = (mtl_reobs['DESI_TARGET'] == 4) & (mtl_reobs['PRIORITY'] == 2)
targets = mtl_reobs[ii]
tiles = Table.read('reduced_tiles.fits')
fbadir = os.path.join(outdir,'fba-reobs')

# %%
plot_counting_assign(targets, tiles, fbadir)

# %%
plt.figure(figsize=(18,6))
plot_fiber_assign(targets, tiles, fbadir)
# Out:
# Total of targets:                  8245
# Targets assigned:                  0
# Estimation of counting fibers:     108000
# Potential targets not assigned:    8245
# Unavailable targets:               0
#
# Percentage over the total number of targets
# Targets assigned:                 0.00%
# Potential targets not assigned:   100.00%
# Unavailable targets:              0.00%
#
# Targets assigned/Counting fibers: 0.00%

# %% [markdown]
# ### **PRIORITY = 3400**

# %%
ii = (mtl_reobs['DESI_TARGET'] == 4) & (mtl_reobs['PRIORITY'] == 3400)
targets = mtl_reobs[ii]

# %%
plot_counting_assign(targets, tiles, fbadir)

# %%
plt.figure(figsize=(18,6))
plot_fiber_assign(targets, tiles, fbadir)
# Out:
# Total of targets:                  28061
# Targets assigned:                  4601
# Estimation of counting fibers:     108000
# Potential targets not assigned:    977
# Unavailable targets:               22483
#
# Percentage over the total number of targets
# Targets assigned:                 16.40%
# Potential targets not assigned:   3.48%
# Unavailable targets:              80.12%
#
# Targets assigned/Counting fibers: 4.26%

# %% [markdown]
# ### **PRIORITY = 3500**

# %%
ii = (mtl_reobs['DESI_TARGET'] == 4) & (mtl_reobs['PRIORITY'] == 3500)
targets = mtl_reobs[ii]

# %%
plot_counting_assign(targets, tiles, fbadir)

# %%
plt.figure(figsize=(18,6))
plot_fiber_assign(targets, tiles, fbadir)
# Out:
# Total of targets:                  4213
# Targets assigned:                  4213
# Estimation of counting fibers:     108000
# Potential targets not assigned:    0
# Unavailable targets:               0
#
# Percentage over the total number of targets
# Targets assigned:                 100.00%
# Potential targets not assigned:   0.00%
# Unavailable targets:              0.00%
#
# Targets assigned/Counting fibers: 3.90%

# %% [markdown]
# ## TO DO:
#
#  - Reduce tiling by Y1 surveysims [DONE]
#  - Increase nside of maps [FAIL]
#  - Increase the area, from 100 to 200 dg² [NEXT]
#  - Consider only PROGRAM=DARK [DONE]
#  - Rerun all notebook [DONE]
#
#  ------------------------------------------------------------------------------------
#
#  - You can add some non-zero warnings before saving the  zcatalog
#  - You could also add some random error within a reasonable range
#  - Save the zcatalog and use it to update the mtl file and run fiberassign again.  zcat.write('./zcat.fits',overwrite=True)
#  - Check that the reobservation occurs as expected.
#  - Continue to try to modify the behaviour of reobservation if we provide information from other classifiers...
#  - Repit using an all target type catalog.
